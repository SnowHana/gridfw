# %%
import yfinance as yf
import pandas as pd

# %%
# Get tickers, random 50
ticker_df = pd.read_csv("/Users/nautilus/gridfw/data/nasdaq_screener_1765967504839.csv")
# ticker_df.columns
# Get stocks that are actually in the market
ticker_df
# Out:
#      Symbol                                               Name Last Sale  \
# 0      AACB  Artius II Acquisition Inc. Class A Ordinary Sh...    $10.31
# 1     AACBR                  Artius II Acquisition Inc. Rights   $0.3516
# 2     AACBU                   Artius II Acquisition Inc. Units    $10.60
# 3      AACG   ATA Creativity Global American Depositary Shares     $0.91
# 4       AAL          American Airlines Group Inc. Common Stock    $15.99
# ...     ...                                                ...       ...
# 4059   ZURA           Zura Bio Limited Class A Ordinary Shares     $4.12
# 4060   ZVRA               Zevra Therapeutics Inc. Common Stock     $8.12
# 4061   ZYBT  Zhengye Biotechnology Holding Limited Ordinary...     $1.86
# 4062   ZYME                        Zymeworks Inc. Common Stock    $25.85
# 4063   ZYXI                            Zynex Inc. Common Stock   $0.3401
#
#       Net Change  % Change    Market Cap         Country  IPO Year    Volume  \
# ...

# %%
ticker_df = ticker_df[ticker_df['Country'].str.match("United States") & ticker_df['Market Cap'] > 0]
tickers = ticker_df["Symbol"].sample(n=50).tolist()

# %%
# df = yf.download(tickers=['TSLA'], auto_adjust=False)

# df = yf.download(["TSLA"], start="2025-11-01", auto_adjust=False)['Adj Close']
# tickers = ["AAPL", "MSFT", "GOOGL", "TSLA"]
df = yf.download(tickers=tickers, start="2025-11-01", auto_adjust=False)['Adj Close']

df
# returns = df.pct_change().dropna()
# returns
# Out:
# [*********************100%***********************]  50 of 50 completed
# Ticker           ACHC    AEI   AIRE       ALGM    BCG   BLFY  BNAI   BTMD  \
# Date
# 2025-11-03  21.309999  2.980  0.541  28.940001  1.630   8.24  4.65  2.830
# 2025-11-04  20.660000  2.600  0.521  27.440001  1.480   8.08  4.24  2.860
# 2025-11-05  20.680000  2.700  0.530  27.430000  1.375   8.21  3.97  2.930
# 2025-11-06  20.260000  2.420  0.508  27.209999  1.490   8.05  3.84  2.840
# 2025-11-07  19.510000  2.420  0.494  26.980000  1.510   8.21  3.75  2.710
# 2025-11-10  18.170000  2.450  0.514  27.600000  1.490   8.07  4.81  2.460
# 2025-11-11  18.240000  2.620  0.563  26.610001  1.410   8.16  4.12  2.605
# 2025-11-12  17.410000  2.640  0.579  26.469999  1.480   8.23  4.06  2.640
# 2025-11-13  16.080000  2.580  0.500  25.285000  1.425   8.20  3.73  2.600
# 2025-11-14  16.020000  2.420  0.479  24.709999  1.730   8.12  4.11  2.520
# 2025-11-17  15.650000  2.350  0.446  23.600000  1.470   7.82  3.90  2.580
# ...

# %%
df.dropna(axis=1)
# Out:
# Ticker           ACHC    AEI   AIRE       ALGM    BCG   BLFY  BNAI   BTMD  \
# Date
# 2025-11-03  21.309999  2.980  0.541  28.940001  1.630   8.24  4.65  2.830
# 2025-11-04  20.660000  2.600  0.521  27.440001  1.480   8.08  4.24  2.860
# 2025-11-05  20.680000  2.700  0.530  27.430000  1.375   8.21  3.97  2.930
# 2025-11-06  20.260000  2.420  0.508  27.209999  1.490   8.05  3.84  2.840
# 2025-11-07  19.510000  2.420  0.494  26.980000  1.510   8.21  3.75  2.710
# 2025-11-10  18.170000  2.450  0.514  27.600000  1.490   8.07  4.81  2.460
# 2025-11-11  18.240000  2.620  0.563  26.610001  1.410   8.16  4.12  2.605
# 2025-11-12  17.410000  2.640  0.579  26.469999  1.480   8.23  4.06  2.640
# 2025-11-13  16.080000  2.580  0.500  25.285000  1.425   8.20  3.73  2.600
# 2025-11-14  16.020000  2.420  0.479  24.709999  1.730   8.12  4.11  2.520
# 2025-11-17  15.650000  2.350  0.446  23.600000  1.470   7.82  3.90  2.580
# 2025-11-18  15.010000  2.400  0.460  23.209999  2.140   7.80  4.00  2.490
# ...

# %%
returns = df.pct_change().dropna(how="all")
# Out:
# /var/folders/7c/q9_nslk55p94jf29j5gtcsxc0000gn/T/ipykernel_39794/3601139298.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = df.pct_change().dropna(how="all")

# %%
# Out:
# Ticker
# ACHC      0
# AEI       0
# AIRE      0
# ALGM      0
# BCG       0
# BLFY      0
# BNAI      0
# BTMD      0
# BWMN      0
# CAKE      0
# COFS      0
# DASH      0
# EDIT      0
# ELTX      0
# ERNA      0
# EXEL      0
# EZPW      0
# FISV      0
# FIVE      0
# FLGT      0
# FRMEP     0
# GCTK      0
# GENK      0
# HCMAW    30
# HWBK      0
# ICUCW    30
# INBS      0
# IVDA      0
# LECO      0
# LMAT      0
# NHPBP     0
# NMFC      0
# NSIT      0
# OPENZ    30
# PBHC      0
# PCYO      0
# REFR      0
# RNTX      0
# SAIA      0
# SAIC      0
# SAIL      0
# SBCWW    30
# SIEB      0
# SOWG      0
# SVC       0
# TVGNW    30
# TWAV      0
# UBFO      0
# WGS       0
# XRAY      0
# dtype: int64

# %%
# Calculate covariance matrix
sigma = returns.cov()
sigma.shape
# sigma
# sigma.to_csv("example4.csv", index=False, header=False)
# Out:
# (10, 10)
